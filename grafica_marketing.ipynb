# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv("marketing.csv")
dataframe
# Out:
#      youtube  facebook  newspaper  sales
# 0     276.12     45.36      83.04  26.52
# 1      53.40     47.16      54.12  12.48
# 2      20.64     55.08      83.16  11.16
# 3     181.80     49.56      70.20  22.20
# 4     216.96     12.96      70.08  15.48
# ..       ...       ...        ...    ...
# 195    45.84      4.44      16.56   9.12
# 196   113.04      5.88       9.72  11.64
# 197   212.40     11.16       7.68  15.36
# 198   340.32     50.40      79.44  30.60
# 199   278.52     10.32      10.44  16.08
#
# [200 rows x 4 columns]

# %%
dataframe.columns
# Out:
# Index(['youtube', 'facebook', 'newspaper', 'sales'], dtype='object')

# %%
valores_eje_y = dataframe["sales"].copy()
valores_eje_x = dataframe.loc[list(np.arange(0, len(dataframe))), ["youtube", "facebook", "newspaper"]].copy()
#len(valores_eje_x["facebook"])==len(valores_eje_y)
plt.figure(figsize=(20,10))
plt.scatter(valores_eje_x["facebook"], valores_eje_y, marker="+", color="r")

#ax =  plt.figure(figsize=(20,20))
#valores_eje_x.hist(bins=20,  ax = ax.gca())
plt.show()
